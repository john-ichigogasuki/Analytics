# %%
import pandas as pd
alpha_abe = pd.read_excel('./TalkData/Conventional_abe.xlsx')
beta_abe = pd.read_excel('./TalkData/Suggestion_abe.xlsx')
alpha_abe
# Out:
#   Speaker                                             Detail
# 0      AI  今日の歩数3365歩って、週平均や月平均に比べてちょっと少なめだね。何か忙しかった？それとも...
# 1    User  最近は発表の準備で忙しくて睡眠時間もへってる．身体を動かす時間はいつもと変わってないつもりだ...
# 2      AI  発表の準備で忙しいときって、無意識のうちに動く時間が減ってるかもしれないね。睡眠時間が減って...
# 3    User         ストレッチは毎日やってるから他になんか簡単に身体を動かすことができる方法ってあるかな
# 4      AI  ストレッチを毎日やってるのはすごくいいね！他に簡単にできる運動としては、デスクワークの合間に...
# 5    User             確かにいいかもしれないけどそれはちょっと面倒だから，なんか楽しいことでお願い
# 6      AI  楽しい運動方法がいいんだね！じゃあ、音楽を活用するのはどうだろう？お気に入りの曲をかけて、そ...
# 7    User             確かに音楽は好きだからいいかもしれない．スマホアプリでそういうのってあるの？
# 8      AI  音楽が好きなら、スマホアプリで音楽を楽しみながら運動できるものがいくつかあるよ！例えば、「Z...

# %%
beta_abe
# Out:
#   Speaker                                             Detail
# 0      AI  今日の歩数3365歩って、週平均や月平均に比べてちょっと少なめだね。何か忙しかった？それとも...
# 1    User  最近は発表の準備で忙しくて睡眠時間もへってる．身体を動かす時間はいつもと変わってないつもりだ...
# 2      AI  発表の準備で忙しいときって、無意識のうちに動く時間が減ってるかもしれないね。睡眠時間が減って...
# 3    User         ストレッチは毎日やってるから他になんか簡単に身体を動かすことができる方法ってあるかな
# 4      AI  ストレッチを毎日やってるのはすごくいいね！他に簡単にできる運動としては、デスクワークの合間に...
# 5    User             確かにいいかもしれないけどそれはちょっと面倒だから，なんか楽しいことでお願い
# 6      AI  楽しい運動方法がいいんだね！じゃあ、音楽を活用するのはどうだろう？お気に入りの曲をかけて、そ...
# 7    User             確かに音楽は好きだからいいかもしれない．スマホアプリでそういうのってあるの？
# 8      AI  音楽が好きなら、スマホアプリで音楽を楽しみながら運動できるものがいくつかあるよ！例えば、「Z...
